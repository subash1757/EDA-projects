# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("Real_estates.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
df.head(36)
# Out:
#     Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.458574             5.682861                   7.009188
# 1       79248.642455             6.002900                   6.730821
# 2       61287.067179             5.865890                   8.512727
# 3       63345.240046             7.188236                   5.586729
# 4       59982.197226             5.040555                   7.839388
# 5       80175.754159             4.988408                   6.104512
# 6       64698.463428             6.025336                   8.147760
# 7       78394.339278             6.989780                   6.620478
# 8       59927.660813             5.362126                   6.393121
# 9       81885.927184             4.423672                   8.167688
# 10      80527.472083             8.093513                   5.042747
# 11      50593.695497             4.496513                   7.467627
# 12      39033.809237             7.671755                   7.250029
# ...

# %%
gmean=df["Avg. Area Income"].median()
gmean
# Out:
# 68804.28640371616

# %%
colname=df.iloc[:,:-2].columns

# %%
colname1=df.iloc[:,-2]

# %%
for i in df[colname]:
    print(i)
    sns.distplot(df[i])
    plt.show()
# Out:
# Avg. Area Income
# Avg. Area House Age
# Avg. Area Number of Rooms
# Avg. Area Number of Bedrooms
# Area Population

# %%
correl=df.corr()
sns.heatmap(correl,annot=True,color="blue")
# Out:
# <AxesSubplot:>

# %%
df.corr()["Price"]
# Out:
# Avg. Area Income                0.639734
# Avg. Area House Age             0.452543
# Avg. Area Number of Rooms       0.335664
# Avg. Area Number of Bedrooms    0.171071
# Area Population                 0.408556
# Price                           1.000000
# Name: Price, dtype: float64

# %%
for i in df[colname]:
    print(i)
    sns.boxplot(df[i])
    plt.show()
# Out:
# Avg. Area Income
# Avg. Area House Age
# Avg. Area Number of Rooms
# Avg. Area Number of Bedrooms
# Area Population

# %%
colname3=df[['Area Population','Avg. Area Number of Bedrooms','Avg. Area House Age','Avg. Area Income']].columns

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
q1=df["Avg. Area Income"].quantile(0.25)

# %%
q3=df["Avg. Area Income"].quantile(0.75)
iqr=q3-q1

# %%
outlier=df[(df["Avg. Area Income"]<q1-1.5*iqr)|(df["Avg. Area Income"]>q3+1.5*iqr)]
outlier
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 12        39033.809237             7.671755                   7.250029
# 39        17796.631190             4.949557                   6.713905
# 411       36100.444227             5.778489                   5.497450
# 558       99629.013581             5.431863                   7.351398
# 693      107701.748378             7.143522                   8.518608
# 844       39411.652788             4.385845                   7.047435
# 962      101928.858060             4.829586                   9.039382
# 1096      97548.310413             5.460973                   6.609396
# 1271      37971.207566             4.291224                   5.807510
# 1459      35963.330809             3.438547                   8.264122
# 1597      39294.036523             5.928585                   5.960676
# 1734     104702.724257             5.575523                   6.932106
# ...

# %%
feature=df[colname]
feature
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population
# 0                             4.09     23086.800503
# ...

# %%
target=df["Price"]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(feature,target,test_size=0.3,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(xtrain,ytrain)
ypred=lr.predict(xtest)

# %%
ypred
# Out:
# array([1555151.93144969, 1583399.08583431,  941481.35482434, ...,
#        1099846.27252109,  974837.76044627, 1731306.80613941])

# %%
lr.coef_
# Out:
# array([2.16398550e+01, 1.65729214e+05, 1.20958349e+05, 1.94909254e+03,
#        1.52262240e+01])

# %%
lr.intercept_
# Out:
# -2645289.8643436683

# %%
sns.distplot(ytest-ypred)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
mae=mean_absolute_error(ytest,ypred)
mse=mean_squared_error(ytest,ypred)
rmse=np.sqrt(mse)
r2=r2_score(ytest,ypred)

# %%
mae
# Out:
# 82745.90894156008

# %%
mse
# Out:
# 10567448570.930983

# %%
rmse
# Out:
# 102798.09614448597

# %%
r2
# Out:
# 0.9166912271539742

# %%
from scipy.stats import skew

# %%
for i in df[colname]:
    print(i)
    print(skew(df[i]))
    sns.distplot(df[i])
    plt.show()
# Out:
# Avg. Area Income
# -0.03370985856853668
# Avg. Area House Age
# -0.007211708023735578
# Avg. Area Number of Rooms
# -0.040983610381965664
# Avg. Area Number of Bedrooms
# 0.37612751568905145
# Area Population
# 0.05063448536127159

# %%
df["Avg. Area Number of Bedrooms"]=np.sqrt(df["Avg. Area Number of Bedrooms"])

# %%
dy=dt[(df["Avg. Area Income"]<q1-1.5*iqr)|(df["Avg. Area Income"]>q3+1.5*iqr)]
dy=dy["Avg. Area Income"].index
dy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1308\732286912.py in <module>
# ----> 1 dy=dt[(df["Avg. Area Income"]<q1-1.5*iqr)|(df["Avg. Area Income"]>q3+1.5*iqr)]
#       2 dy=dy["Avg. Area Income"].index
#       3 dy
#
# NameError: name 'dt' is not defined

# %%
df.drop("Area Population",axis=1,inplace=True)

# %%
df[(df["Avg. Area Number of Bedrooms"]<q1-1.5*iqr)|(df["Avg. Area Number of Bedrooms"]>q3+1.5*iqr)]

# %%
pd.set_option('display.max_rows',None)

# %%
df.loc[dy,"Avg. Area Income"]=np.nan
df["Avg. Area Income"].fillna(0,inplace=True)
mmean=df["Avg. Area Income"].median()
mmean

# %%
df["Avg. Area Income"].replace(0,mmean,inplace=True)

# %%
df.info()

# %%
df["Avg. Area Income"]==dt
from sklearn.impute import SimpleImputer
si=SimpleImputer(df["Avg. Area Income"]==dt,strategy="mean")
df["Avg. Area Income"]=si.fit_transform(df[["Avg. Area Income"]])

# %%
dy=df["Avg. Area Income"]==dt
df["Avg. Area Income"].map(dy,np.nan)
mmean=df["Avg. Area Income"].mean()
df["Avg. Area Income"].fill(mmean)
